# %%
import os 
import pandas as pd
import numpy as np

# %% [markdown]
# ###### Lets import important module and add in working location as usual.  Here we will use the dataframe that I previously processed in Step1
# Here I removed some of the columns that I probably won't be using

# %%
os.getcwd()
one_level_up = os.path.dirname(os.getcwd())
df = pd.read_csv(one_level_up + '\\data\\processed\\processed_tweets.csv', index_col=0)
df = df.drop(['tweet', 'punct','token'], axis  = 1)
df
# Out:
#      politican party  retweet  \
# 0        Trump     R    False
# 1        Trump     R    False
# 2        Trump     R    False
# 3        Trump     R    False
# 4        Trump     R    False
# ...        ...   ...      ...
# 1069     Pence     R    False
# 1070     Pence     R    False
# 1071     Pence     R    False
# 1072     Pence     R    False
# 1073     Pence     R    False
#
#                                             tweet_web_r   ARI    DCR     TS  \
# 0     Will be interviewed by @seanhannity tonight at...  10.9   6.86   6.86
# 1                               WELCOME BACK BASEBALL!   11.5   0.15   0.15
# 2       White House Press Conference at 5:15 P.M. Live!   6.1   6.01   6.01
# 3     The Suburban Housewives of America must read t...   9.0   6.71   6.71
# 4     Obama, who wouldn’t even endorse Biden until e...  10.6   8.44   8.44
# ...                                                 ...   ...    ...    ...
# 1069  HUGE news: The NASDAQ hit an all-time record h...  11.8   6.88   6.88
# 1070  TONIGHT at 5PM: Joining @LouDobbs to talk abou...  14.1   8.73   8.73
# 1071  Proud to work hand-in-hand with @CDCgov &amp; ...  16.6   9.79   9.79
# 1072  Insightful and thoughtful meeting with @theang...  22.9  12.23  12.23
# 1073  Today is a Historic Day for our Nation. The Se...   9.6   9.93   9.93
#
#                                               lem_token
# 0     ['Will', 'interviewed', 'seanhannity', 'tonigh...
# 1                       ['WELCOME', 'BACK', 'BASEBALL']
# 2     ['White', 'House', 'Press', 'Conference', '515...
# 3     ['The', 'Suburban', 'Housewives', 'America', '...
# 4     ['Obama', '’', 'even', 'endorse', 'Biden', 'ev...
# ...                                                 ...
# 1069  ['HUGE', 'news', 'The', 'NASDAQ', 'hit', 'allt...
# 1070  ['TONIGHT', '5PM', 'Joining', 'LouDobbs', 'tal...
# 1071  ['Proud', 'work', 'handinhand', 'CDCgov', 'amp...
# 1072  ['Insightful', 'thoughtful', 'meeting', 'thean...
# 1073  ['Today', 'Historic', 'Day', 'Nation', 'The', ...
#
# [1074 rows x 8 columns]

# %% [markdown]
# ###### Ok Now we have the data frame.  Let see if we can run some sentiment code and evalute the sentiment of the tweets

# %%
import nltk
#nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
df['sentiment_score'] = df['tweet_web_r'].apply(analyser.polarity_scores)
compound_score = []
sentiment_score = list(df['sentiment_score'])

for i in range(len(df['sentiment_score'])):
    compound_score.append(sentiment_score[i]['compound'])
    
df['sentiment_score'] = compound_score
df
# Out:
#      politican party  retweet  \
# 0        Trump     R    False
# 1        Trump     R    False
# 2        Trump     R    False
# 3        Trump     R    False
# 4        Trump     R    False
# ...        ...   ...      ...
# 1069     Pence     R    False
# 1070     Pence     R    False
# 1071     Pence     R    False
# 1072     Pence     R    False
# 1073     Pence     R    False
#
#                                             tweet_web_r   ARI    DCR     TS  \
# 0     Will be interviewed by @seanhannity tonight at...  10.9   6.86   6.86
# 1                               WELCOME BACK BASEBALL!   11.5   0.15   0.15
# 2       White House Press Conference at 5:15 P.M. Live!   6.1   6.01   6.01
# 3     The Suburban Housewives of America must read t...   9.0   6.71   6.71
# 4     Obama, who wouldn’t even endorse Biden until e...  10.6   8.44   8.44
# ...                                                 ...   ...    ...    ...
# 1069  HUGE news: The NASDAQ hit an all-time record h...  11.8   6.88   6.88
# 1070  TONIGHT at 5PM: Joining @LouDobbs to talk abou...  14.1   8.73   8.73
# 1071  Proud to work hand-in-hand with @CDCgov &amp; ...  16.6   9.79   9.79
# 1072  Insightful and thoughtful meeting with @theang...  22.9  12.23  12.23
# 1073  Today is a Historic Day for our Nation. The Se...   9.6   9.93   9.93
#
#                                               lem_token  sentiment_score
# 0     ['Will', 'interviewed', 'seanhannity', 'tonigh...           0.6219
# 1                       ['WELCOME', 'BACK', 'BASEBALL']           0.5093
# 2     ['White', 'House', 'Press', 'Conference', '515...           0.0000
# 3     ['The', 'Suburban', 'Housewives', 'America', '...          -0.5423
# 4     ['Obama', '’', 'even', 'endorse', 'Biden', 'ev...           0.3182
# ...                                                 ...              ...
# 1069  ['HUGE', 'news', 'The', 'NASDAQ', 'hit', 'allt...           0.5147
# 1070  ['TONIGHT', '5PM', 'Joining', 'LouDobbs', 'tal...           0.4019
# 1071  ['Proud', 'work', 'handinhand', 'CDCgov', 'amp...           0.4767
# 1072  ['Insightful', 'thoughtful', 'meeting', 'thean...           0.3818
# 1073  ['Today', 'Historic', 'Day', 'Nation', 'The', ...           0.0000
#
# [1074 rows x 9 columns]

# %% [markdown]
# The Compound score is a metric that calculates the sum of all the lexicon ratings which have been normalized between -1(most extreme negative) and +1 (most extreme positive).
#
# <br>positive sentiment : (compound score >= 0.05)
# <br>neutral sentiment : (compound score > -0.05) and (compound score < 0.05)
# <br>negative sentiment : (compound score <= -0.05)
#
# <br>Now we have positive negative and neutral let see if we can see the trend on different politician

# %%
def sentiment_grouping(sentiment_compound):
    if sentiment_compound >= 0.05:
        return 'Positive'
    elif (sentiment_compound > -0.05 and sentiment_compound < 0.05):
        return 'Neutral'
    elif sentiment_compound <= -0.05:
        return 'Negative'

df['sentiment'] = df['sentiment_score'].apply(sentiment_grouping)
df.groupby(['politican', 'sentiment']).count()['party']
# Out:
# politican  sentiment
# Biden      Negative      59
#            Neutral       47
#            Positive      89
# Cruz       Negative      56
#            Neutral       39
#            Positive      69
# McConell   Negative      61
#            Neutral       31
#            Positive     101
# Pence      Negative       9
#            Neutral       41
#            Positive      91
# Sanders    Negative      57
#            Neutral       23
#            Positive      93
# Trump      Negative      10
#            Neutral        7
#            Positive      32
# Warren     Negative      72
#            Neutral       36
#            Positive      51
# Name: party, dtype: int64

# %% [markdown]
# Ok we see that most of the people tweets are positive except for Warren who has more negative than positive tweets, also i remove a lot of retweet from donald trump...  perhaps we shouldn't remove retweet or perhaps we need to get more data

# %%
df
# Out:
#      politican party  retweet  \
# 0        Trump     R    False
# 1        Trump     R    False
# 2        Trump     R    False
# 3        Trump     R    False
# 4        Trump     R    False
# ...        ...   ...      ...
# 1069     Pence     R    False
# 1070     Pence     R    False
# 1071     Pence     R    False
# 1072     Pence     R    False
# 1073     Pence     R    False
#
#                                             tweet_web_r   ARI    DCR     TS  \
# 0     Will be interviewed by @seanhannity tonight at...  10.9   6.86   6.86
# 1                               WELCOME BACK BASEBALL!   11.5   0.15   0.15
# 2       White House Press Conference at 5:15 P.M. Live!   6.1   6.01   6.01
# 3     The Suburban Housewives of America must read t...   9.0   6.71   6.71
# 4     Obama, who wouldn’t even endorse Biden until e...  10.6   8.44   8.44
# ...                                                 ...   ...    ...    ...
# 1069  HUGE news: The NASDAQ hit an all-time record h...  11.8   6.88   6.88
# 1070  TONIGHT at 5PM: Joining @LouDobbs to talk abou...  14.1   8.73   8.73
# 1071  Proud to work hand-in-hand with @CDCgov &amp; ...  16.6   9.79   9.79
# 1072  Insightful and thoughtful meeting with @theang...  22.9  12.23  12.23
# 1073  Today is a Historic Day for our Nation. The Se...   9.6   9.93   9.93
#
#                                               lem_token  sentiment_score  \
# 0     ['Will', 'interviewed', 'seanhannity', 'tonigh...           0.6219
# 1                       ['WELCOME', 'BACK', 'BASEBALL']           0.5093
# 2     ['White', 'House', 'Press', 'Conference', '515...           0.0000
# 3     ['The', 'Suburban', 'Housewives', 'America', '...          -0.5423
# 4     ['Obama', '’', 'even', 'endorse', 'Biden', 'ev...           0.3182
# ...                                                 ...              ...
# 1069  ['HUGE', 'news', 'The', 'NASDAQ', 'hit', 'allt...           0.5147
# 1070  ['TONIGHT', '5PM', 'Joining', 'LouDobbs', 'tal...           0.4019
# 1071  ['Proud', 'work', 'handinhand', 'CDCgov', 'amp...           0.4767
# 1072  ['Insightful', 'thoughtful', 'meeting', 'thean...           0.3818
# 1073  ['Today', 'Historic', 'Day', 'Nation', 'The', ...           0.0000
#
#      sentiment
# 0     Positive
# 1     Positive
# 2      Neutral
# 3     Negative
# 4     Positive
# ...        ...
# 1069  Positive
# 1070  Positive
# 1071  Positive
# 1072  Positive
# 1073   Neutral
#
# [1074 rows x 10 columns]

# %%
politican = ['Trump','Biden','Sanders','Warren','McConell','Cruz','Pence']
plot = []
### over we found out that Pence doesn't actually tweet.  All he does is retweet himself.... so we actually 
### collect data from wrong twitter account

#politican.remove('Pence')
"""
plot = []
for idx, name in enumerate(politican):
    politican_df = df_noRT[df_noRT['politican'] == name] 
    politican_df_tweet = " ".join(review for review in politican_df.tweet_web_r)
    wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(politican_df_tweet)
    plot.append(wordcloud)
"""
